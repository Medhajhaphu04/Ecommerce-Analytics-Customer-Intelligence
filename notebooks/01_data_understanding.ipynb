# %%
import pandas as pd

# %% [markdown]
# **Loading the Dataset**

# %%
import pandas as pd

customers = pd.read_csv("../data/olist_customers_dataset.csv")

orders = pd.read_csv("../data/olist_orders_dataset.csv")

order_items = pd.read_csv("../data/olist_order_items_dataset.csv")

payments = pd.read_csv("../data/olist_order_payments_dataset.csv")

reviews = pd.read_csv("../data/olist_order_reviews_dataset.csv")

products = pd.read_csv("../data/olist_products_dataset.csv")

sellers = pd.read_csv("../data/olist_sellers_dataset.csv")

translation = pd.read_csv(
    "../data/product_category_name_translation.csv"
)

# %% [markdown]
# **Dataset Overview**

# %%
tables = {
    "customers": customers,
    "orders": orders,
    "order_items": order_items,
    "payments": payments,
    "reviews": reviews,
    "products": products,
    "sellers": sellers
}

for name, df in tables.items():
    print(
        f"{name}: {df.shape}"
    )
# Out:
# customers: (99441, 5)
# orders: (99441, 8)
# order_items: (112650, 7)
# payments: (103886, 5)
# reviews: (99224, 7)
# products: (32951, 9)
# sellers: (3095, 4)

# %% [markdown]
# **Column Analysis**

# %%
for name, df in tables.items():
    print("\n")
    print(name.upper())
    print(df.columns.tolist())
# Out:
# CUSTOMERS
# ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
#
#
# ORDERS
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
#
#
# ORDER_ITEMS
# ['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value']
#
#
# PAYMENTS
# ['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
#
#
# REVIEWS
# ['review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp']
#
#
# PRODUCTS
# ['product_id', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
#
#
# SELLERS
# ...

# %% [markdown]
# **Data Types**

# %%
for name, df in tables.items():
    print(
        f"{name}: {df.info()}"
    )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# customers: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
# ...

# %% [markdown]
# **Missing Value Analysis**

# %%
for name, df in tables.items():
    print("="*50)
    print(name)
    print(df.isnull().sum())
# Out:
# ...
# customers
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
# ...
# orders
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
# ...
# order_items
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
# ...
# payments
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
# ...
# reviews
# review_id                      0
# order_id                       0
# ...

# %% [markdown]
# **Duplicate Analysis**

# %%
for name, df in tables.items():
    print(
        name,
        df.duplicated().sum()
    )
# Out:
# customers 0
# orders 0
# order_items 0
# payments 0
# reviews 0
# products 0
# sellers 0

# %% [markdown]
# **Primary Key Validation**

# %%
print("Customers")

print("Total Rows:", len(customers))

print(
    "Unique customer_id:",
    customers["customer_id"].nunique()
)

print(
    "Primary Key Valid:",
    len(customers)
    ==
    customers["customer_id"].nunique()
)
# Out:
# Customers
# Total Rows: 99441
# Unique customer_id: 99441
# Primary Key Valid: True

# %%
print("Orders")

print("Total Rows:", len(orders))

print(
    "Unique order_id:",
    orders["order_id"].nunique()
)

print(
    "Primary Key Valid:",
    len(orders)
    ==
    orders["order_id"].nunique()
)
# Out:
# Orders
# Total Rows: 99441
# Unique order_id: 99441
# Primary Key Valid: True

# %%
print("Products")

print("Total Rows:", len(products))

print(
    "Unique product_id:",
    products["product_id"].nunique()
)

print(
    "Primary Key Valid:",
    len(products)
    ==
    products["product_id"].nunique()
)
# Out:
# Products
# Total Rows: 32951
# Unique product_id: 32951
# Primary Key Valid: True

# %%
print("Sellers")

print("Total Rows:", len(sellers))

print(
    "Unique seller_id:",
    sellers["seller_id"].nunique()
)

print(
    "Primary Key Valid:",
    len(sellers)
    ==
    sellers["seller_id"].nunique()
)
# Out:
# Sellers
# Total Rows: 3095
# Unique seller_id: 3095
# Primary Key Valid: True

# %%
print("Reviews")

print("Total Rows:", len(reviews))

print(
    "Unique review_id:",
    reviews["review_id"].nunique()
)
# Out:
# Reviews
# Total Rows: 99224
# Unique review_id: 98410

# %% [markdown]
# **Relationship Validation**

# %% [markdown]
# 1. Customers ↔ Orders

# %%
orders_customer_match = (
    orders["customer_id"]
    .isin(customers["customer_id"])
    .all()
)

print(
    "Customers ↔ Orders:",
    orders_customer_match
)
# Out:
# Customers ↔ Orders: True

# %% [markdown]
# 2. Orders ↔ Order Items

# %%
order_items_match = (
    order_items["order_id"]
    .isin(orders["order_id"])
    .all()
)

print(
    "Orders ↔ Order Items:",
    order_items_match
)
# Out:
# Orders ↔ Order Items: True

# %% [markdown]
# 3. Products ↔ Order Items

# %%
product_match = (
    order_items["product_id"]
    .isin(products["product_id"])
    .all()
)

print(
    "Products ↔ Order Items:",
    product_match
)
# Out:
# Products ↔ Order Items: True

# %% [markdown]
# 4. Sellers ↔ Order Items

# %%
seller_match = (
    order_items["seller_id"]
    .isin(sellers["seller_id"])
    .all()
)

print(
    "Sellers ↔ Order Items:",
    seller_match
)
# Out:
# Sellers ↔ Order Items: True

# %% [markdown]
# 5. Orders ↔ Payments

# %%
payment_match = (
    payments["order_id"]
    .isin(orders["order_id"])
    .all()
)

print(
    "Orders ↔ Payments:",
    payment_match
)
# Out:
# Orders ↔ Payments: True

# %% [markdown]
# 6. Orders ↔ Reviews

# %%
review_match = (
    reviews["order_id"]
    .isin(orders["order_id"])
    .all()
)

print(
    "Orders ↔ Reviews:",
    review_match
)
# Out:
# Orders ↔ Reviews: True

# %%
relationships = {
    "Customers ↔ Orders":
        orders["customer_id"]
        .isin(customers["customer_id"])
        .all(),

    "Orders ↔ Order Items":
        order_items["order_id"]
        .isin(orders["order_id"])
        .all(),

    "Products ↔ Order Items":
        order_items["product_id"]
        .isin(products["product_id"])
        .all(),

    "Sellers ↔ Order Items":
        order_items["seller_id"]
        .isin(sellers["seller_id"])
        .all(),

    "Orders ↔ Payments":
        payments["order_id"]
        .isin(orders["order_id"])
        .all(),

    "Orders ↔ Reviews":
        reviews["order_id"]
        .isin(orders["order_id"])
        .all()
}

pd.DataFrame(
    relationships.items(),
    columns=["Relationship", "Valid"]
)
# Out:
#              Relationship  Valid
# 0      Customers ↔ Orders   True
# 1    Orders ↔ Order Items   True
# 2  Products ↔ Order Items   True
# 3   Sellers ↔ Order Items   True
# 4       Orders ↔ Payments   True
# 5        Orders ↔ Reviews   True

# %% [markdown]
# **Timestamp Exploration**

# %% [markdown]
# 1.  Convert Datetime Columns

# %%
orders["order_purchase_timestamp"] = pd.to_datetime(
    orders["order_purchase_timestamp"]
)

orders["order_approved_at"] = pd.to_datetime(
    orders["order_approved_at"]
)

orders["order_delivered_carrier_date"] = pd.to_datetime(
    orders["order_delivered_carrier_date"]
)

orders["order_delivered_customer_date"] = pd.to_datetime(
    orders["order_delivered_customer_date"]
)

orders["order_estimated_delivery_date"] = pd.to_datetime(
    orders["order_estimated_delivery_date"]
)

# %% [markdown]
# 2. Dataset Time Range

# %%
print(
    "Start Date:",
    orders["order_purchase_timestamp"].min()
)

print(
    "End Date:",
    orders["order_purchase_timestamp"].max()
)
# Out:
# Start Date: 2016-09-04 21:15:19
# End Date: 2018-10-17 17:30:18

# %% [markdown]
# 3. Number of Days Covered

# %%
dataset_duration = (
    orders["order_purchase_timestamp"].max()
    -
    orders["order_purchase_timestamp"].min()
)

print(
    "Dataset Duration:",
    dataset_duration
)
# Out:
# Dataset Duration: 772 days 20:14:59

# %% [markdown]
# 4. Orders Per Year

# %%
orders["purchase_year"] = (
    orders["order_purchase_timestamp"]
    .dt.year
)

orders["purchase_year"].value_counts().sort_index()
# Out:
# purchase_year
# 2016      329
# 2017    45101
# 2018    54011
# Name: count, dtype: int64

# %% [markdown]
# 5. Orders Per Month

# %%
orders["purchase_month"] = (
    orders["order_purchase_timestamp"]
    .dt.to_period("M")
)

orders["purchase_month"].value_counts().sort_index()
# Out:
# purchase_month
# 2016-09       4
# 2016-10     324
# 2016-12       1
# 2017-01     800
# 2017-02    1780
# 2017-03    2682
# 2017-04    2404
# 2017-05    3700
# 2017-06    3245
# 2017-07    4026
# 2017-08    4331
# 2017-09    4285
# 2017-10    4631
# 2017-11    7544
# 2017-12    5673
# 2018-01    7269
# 2018-02    6728
# 2018-03    7211
# 2018-04    6939
# 2018-05    6873
# 2018-06    6167
# 2018-07    6292
# 2018-08    6512
# 2018-09      16
# 2018-10       4
# Freq: M, Name: count, dtype: int64

# %% [markdown]
# # Business Entity Understanding
#
# ## Customers
# Stores customer demographic and location information.
#
# ## Orders
# Stores order lifecycle information from purchase to delivery.
#
# ## Order Items
# Stores products purchased within orders.
#
# ## Products
# Stores product metadata and characteristics.
#
# ## Payments
# Stores payment details and transaction values.
#
# ## Reviews
# Stores customer satisfaction and feedback.
#
# ## Sellers
# Stores seller information and geographical details.

# %% [markdown]
# # Initial Business Observations
#
# 1. The dataset contains complete customer purchase journeys.
#
# 2. Revenue can be calculated using product prices and payment information.
#
# 3. Customer satisfaction can be measured using review scores.
#
# 4. Customer value can be estimated using purchase frequency and total spending.
#
# 5. The dataset supports customer segmentation using RFM analysis.
#
# 6. The dataset supports sales forecasting using historical order data.
#
# 7. Product performance can be analyzed at category and seller levels.
#
# 8. The relational structure makes the dataset suitable for advanced SQL analytics involving joins, CTEs, and window functions.
#
# 9. The dataset can support customer lifetime value estimation.
#
# 10. The dataset is suitable for building an AI-powered business intelligence platform.
